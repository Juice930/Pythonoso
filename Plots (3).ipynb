# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
y=np.array([0,3,2,6,2])

# %%
plt.plot(y)
plt.xlabel(r'$x$')
plt.ylabel(r'$y^2$')
plt.show()

# %%
x=np.arange(0,100,0.01)
y=x**2
lims=[0,4,0,10]
plt.plot(x,y,'b')
plt.xlabel('X')
plt.axis(lims)
plt.ylabel(r'$Y^2$')
plt.show()

# %%
x=np.linspace(0,15,100)
y1=x
y2=x**2
y3=np.cos(x)
y4=np.exp(x)
lims=[0,15,-2,20]
plt.plot(x,y1,'r',x,y2,'b',x,y3,'g',x,y4,'k')
plt.xlabel(r'$x$')
plt.ylabel(r'$f(x)$')
plt.axis(lims)
plt.legend([r'$x$',r'$x^2$',r'$\cos(x)$',r'$e^x$'])
plt.show()

# %%
y=x**2
y1=x**3
lin0,=plt.plot(x,y)
lin0.set_linewidth(10)
lin0.set_alpha(0.1) #Transparencia
lin1,=plt.plot(x,y1)
lin1.set_linewidth(5)
lin1.set_alpha(0.4)
plt.show()

# %%
plt.figure(1)
y1=x**2
plt.plot(x,y1)

plt.figure(2)
y2=np.log(x)
plt.plot(x,y2)

plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:6: RuntimeWarning: divide by zero encountered in log

# %%
plt.figure(figsize=(5,5))
plt.plot(x,y)
plt.show()

# %%
plt.figure(1)
plt.subplot(211)#2 gráficas, 2 rens, primera parte
y1=x**2
plt.plot(x,y1)

plt.subplot(212)#2 gráficas, 2 rens, segunda parte
y2=np.log(x)
plt.plot(x,y2)

plt.show()
# Out:
# C:\Users\Guillermo1\Anaconda2\lib\site-packages\ipykernel\__main__.py:8: RuntimeWarning: divide by zero encountered in log

# %%
plt.figure(1)
plt.subplot(1,2,1)#2 gráficas, 2 cols, primera parte
y1=x**2
plt.plot(x,y1)

plt.subplot(1,2,2)#2 gráficas, 2 cols, segunda parte
y2=np.log(x)
plt.plot(x,y2)

plt.show()
# Out:
# C:\Users\Guillermo1\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: RuntimeWarning: divide by zero encountered in log

# %%
fig=plt.figure(1)
ax1=plt.subplot(211)#2 gráficas, 2 rens, primera parte
y1=x**2
ax1.plot(x,y1)
ax1.text(3.5,200,"Pa k quieres saber eso? jaja Saludos")
ax2=plt.subplot(212)#2 gráficas, 2 rens, segunda parte
y2=np.sin(x)
ax2.grid(True)
ax2.plot(x,y2)
#ax1.tick_params() #No sé qué hace
ax1.semilogx()
ax1.invert_yaxis()
ax2.invert_xaxis()
plt.show()

# %%
def fun(x):
    return np.exp(-x)

# %%
x=np.linspace(0,100,100)
plt.plot(fun(x))
plt.show()

# %%
def sigma(t):
    return np.array([t*np.cos(2*t),np.sin(t)])
t=np.linspace(-10*np.pi,10*np.pi,1000)
x,y=sigma(t)[0],sigma(t)[1]
lims=[-40,40,-2,2]
plt.axis(lims)
plt.plot(x,y)
plt.show()

# %%
x=np.arange(-4,3,0.01)
y=x**4+4*x**3-7*x**2-22*x+24
lims=[-4,3,-30,10]
plt.figure(figsize=(10,10))
plt.plot(x,y,'b')
y=0*x
plt.grid(True)
plt.plot(x,y,'k')
plt.xlabel(r'$x$')
plt.axis(lims)
plt.ylabel(r'$f(x)$')
plt.show()

# %%
x=np.arange(-5,5,0.01)
y1=(x+1)*(x+2)*(x-3)*(x+4)*x
y2=-x*(x-3)*(x+2)*(x-2)
y3=-(x+2)*(x-1)*(x+3)*(x-2)
y4=(x+4)*(x-4)*(x+1)*x
lims=[-5,5,-100,30]
plt.figure(figsize=(10,10))
plt.plot(x,y1,'b')
plt.plot(x,y2,'r')
plt.plot(x,y3,'y')
plt.plot(x,y4,'g')
y=0*x
plt.grid(True)
plt.plot(x,y,'k')
plt.xlabel(r'$x$')
plt.axis(lims)
plt.ylabel(r'$f(x)$')
plt.show()

# %%
x=np.arange(0,4,0.01)
y1=2+np.sqrt(-x**2+4*x)
y2=2-np.sqrt(-x**2+4*x)
lims=[0,4,0,4]
plt.figure(figsize=(10,10))
plt.plot(x,y1,'b')
plt.grid(True)
plt.plot(x,y2,'b')
plt.xlabel(r'$x$')
plt.axis(lims)
plt.ylabel(r'$y$')
plt.show()

# %%
x=np.arange(-6,0,0.01)
y1=2+np.sqrt(-x**2-6*x)
y2=2-np.sqrt(-x**2-6*x)
lims=[-6,0,-1,5]
plt.figure(figsize=(10,10))
plt.plot(x,y1,'b')
y=0*x
plt.grid(True)
plt.plot(x,y,'k')
plt.plot(x,y2,'b')
plt.xlabel(r'$x$')
plt.axis(lims)
plt.ylabel(r'$y$')
plt.show()

# %%
x=np.arange(-5,3,0.01)
y1=-2+np.sqrt(-x**2-2*x+15)
y2=-2-np.sqrt(-x**2-2*x+15)
lims=[-5,3,-6,2]
plt.figure(figsize=(7,7))
plt.plot(x,y1,'b')
y=0*x
plt.grid(True)
plt.plot(x,y,'k')
plt.plot(x,y2,'b')
plt.xlabel(r'$x$')
plt.axis(lims)
plt.ylabel(r'$y$')
plt.show()

# %%
a=-4,0
x=np.arange(a[0],a[1],0.01)
y1=np.sqrt(-x**2-4*x)
y2=-np.sqrt(-x**2-4*x)
lims=[a[0],a[1],-2,2]
plt.figure(figsize=(7,7))
plt.plot(x,y1,'b')
y=0*x
plt.grid(True)
plt.plot(x,y,'k')
plt.plot(x,y2,'b')
plt.xlabel(r'$x$')
plt.axis(lims)
plt.ylabel(r'$y$')
plt.show()

# %%
a=-2,2
x=np.arange(a[0],a[1],0.01)
y1=3+np.sqrt(-x**2+4)
y2=3-np.sqrt(-x**2+4)
lims=[a[0],a[1],1,5]
plt.figure(figsize=(7,7))
plt.plot(x,y1,'b')
y=0*x
plt.grid(True)
plt.plot(x,y,'k')
plt.plot(x,y2,'b')
plt.xlabel(r'$x$')
plt.axis(lims)
plt.ylabel(r'$y$')
plt.show()

# %%
a=1,7
x=np.arange(a[0],a[1],0.01)
y1=np.sqrt(-x**2+8*x-7)
y2=-np.sqrt(-x**2+8*x-7)
lims=[a[0],a[1],-3,3]
plt.figure(figsize=(7,7))
plt.plot(x,y1,'b')
y=0*x
plt.grid(True)
plt.plot(x,y,'k')
plt.plot(x,y2,'b')
plt.xlabel(r'$x$')
plt.axis(lims)
plt.ylabel(r'$y$')
plt.show()

# %%
a=-3-5,-3+5
x=np.arange(a[0],a[1],0.01)
y1=2+np.sqrt(-x**2-6*x+16)
y2=2-np.sqrt(-x**2-6*x+16)
lims=[a[0],a[1],-3,7]
plt.figure(figsize=(7,7))
plt.plot(x,y1,'b')
y=0*x

plt.grid(True)
plt.plot(x,y,'k')
plt.plot(x,y2,'b')
plt.xlabel(r'$x$')
plt.axis(lims)
plt.ylabel(r'$y$')
plt.show()

# %%
a=0,14
x=np.arange(a[0],a[1],0.01)
y=np.cos(3*x)+np.cos(x)+np.sin(3*x)+np.sin(5*x)
y1=np.cos(3*x)-np.cos(x)-np.sin(2*x)
lims=[a[0],a[1],-4,4]
plt.figure(figsize=(7,7))
plt.grid(True)
plt.plot(x,y,'b')
plt.plot(x,y1,'r')
plt.xlabel(r'$x$')
plt.axis(lims)
plt.ylabel(r'$y$')
plt.show()

# %%
a=0,14
x=np.arange(a[0],a[1],0.01)
y=np.cos(3*x)+np.cos(x)+np.sin(3*x)+np.sin(5*x)
z=True
y1,y2=[],[]
j=list(range(1400))
for i in x:
    if i%3==0:
        z=not z
    if z==True:
        y1.append(3)
    else:
        y1.append(-3)
k,b=0,0
for i in x:
    if i%2==0 and i!=0:
        z=not z
        b=x[k-1]
    if z==True:
        y2.append(float(x[k])-b)
    else:
        y2.append(float(-x[k])+b)
    k+=1
       
def gauss(x,mu,sig):
    return np.exp(-np.power(x-mu,2.)/(2*np.power(sig,2.)))

lims=[a[0],a[1],-4,4]
plt.figure(figsize=(7,7))
plt.grid(True)
plt.plot(x,y,'b')
plt.plot(x,y1,'r')
plt.plot(x,y2,'g')
plt.plot(x,3*gauss(x,7,1),'y')
plt.xlabel(r'$x$')
plt.axis(lims)
plt.ylabel(r'$y$')
plt.show()

# %%
a=0,3
x=np.arange(a[0],a[1],0.01)
y=np.exp(-2*x)*np.cos(30*x)+2
y1=np.exp(-2*x)+2
y2=np.cos(30*x)+2
lims=[a[0],a[1],0,3]
plt.figure(figsize=(7,7))
plt.grid(True)
plt.plot(x,y,'b',label=r'$e^{-2t}\cdot cos(30x)+2$')
plt.plot(x,y1,'g',label=r'$e^{-2t}+2$')
plt.plot(x,y2,'r',label=r'$cos(30t)+2$')
plt.xlabel(r'$x$')
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.axis(lims)
plt.ylabel(r'$y$')
plt.show()

# %%
a=-5,5
x=np.arange(a[0],a[1],0.01)
y=np.tanh(x)/x
lims=[a[0],a[1],0,1.2]
plt.figure(figsize=(7,7))
plt.grid(True)
plt.plot(x,y,'b')
#plt.plot(x,y1,'g',label=r'$e^{-2t}+2$')
#plt.plot(x,y2,'r',label=r'$cos(30t)+2$')
plt.xlabel(r'$x$')
#plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.axis(lims)
plt.ylabel(r'$y$')
plt.show()

# %%
a=-5,0,3,7
x=np.arange(a[0],a[1],0.01)
x2=np.arange(a[2],a[3],0.01)
y=(x+3)/(x-1)
z=(x2+3)/(x2-1)
lims=[a[0],a[3],-10,10]
plt.figure(figsize=(7,7))
plt.grid(True)
plt.plot(x,y,'b')
plt.plot(x2,z,'b')
#plt.plot(x,y1,'g',label=r'$e^{-2t}+2$')
#plt.plot(x,y2,'r',label=r'$cos(30t)+2$')
plt.xlabel(r'$x$')
#plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.axis(lims)
plt.ylabel(r'$y$')
plt.show()

# %%
a=-0.999,5
x=np.arange(a[0],a[1],0.01)
y=np.sqrt(3*x+3)/np.log(x+2)
lims=[a[0],a[1],0,1.2]
plt.figure(figsize=(7,7))
plt.grid(True)
plt.plot(x,y,'b')
#plt.plot(x,y1,'g',label=r'$e^{-2t}+2$')
#plt.plot(x,y2,'r',label=r'$cos(30t)+2$')
plt.xlabel(r'$x$')
#plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.axis(lims)
plt.ylabel(r'$y$')
plt.show()

# %%
a=-6,16
x=np.arange(a[0],a[1],0.01)
y1=-4+(4./5)*np.sqrt(x**2-10*x)
y2=-4-(4./5)*np.sqrt(x**2-10*x)
lims=[a[0],a[1],-14,6]
fig=plt.figure(figsize=(7,7))
plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-14,7,1))
plt.plot(x,y1,'b')
plt.plot(x,y2,'b')
plt.plot(5,-4,'o')
#plt.plot(x,y1,'g',label=r'$e^{-2t}+2$')
#plt.plot(x,y2,'r',label=r'$cos(30t)+2$')
plt.xlabel(r'$x$')
#plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.axis(lims)
plt.ylabel(r'$y$')
plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:4: RuntimeWarning: invalid value encountered in sqrt

# %%
a=-2,4
x=np.arange(a[0],a[1],0.01)
y=x/3.-1
lims=[a[0],a[1],-2,2]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-2,6,1))
plt.plot(x,y,'b')
plt.plot(x,0*x,'k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.show()

# %%
a=-2,6
x=np.arange(a[0],a[1],0.01)
y=-2*x+4
lims=[a[0],a[1],-3,10]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-3,10,1))
plt.plot(x,y,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.show()

# %%
a=-2,6
x=np.arange(a[0],a[1],0.01)
y=-2./7*(x+0.5)
lims=[a[0],a[1],-3,1]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-3,10,0.5))
plt.plot(x,y,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.show()

# %%
a=-2,5
x=np.arange(a[0],a[1],0.01)
y=3/2.*x
lims=[a[0],a[1],-3,7]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-3,10,1))
plt.plot(x,y,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$V [V]$')
plt.xlabel(r'$I [A]$')
plt.show()

# %%
a=-5,5
x=np.arange(a[0],a[1],0.01)
y=-x/3.-1
y2=3*x-11
lims=[a[0],a[1],-3,2]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-3,10,0.5))
plt.plot(x,y,'b')
#plt.plot(x,y2,'r')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()

# %%
a=0,10
x=np.arange(a[0],a[1],0.01)
y=(4*(x-2))**0.5
y2=-(4*(x-2))**0.5
lims=[a[0],a[1],-5,5]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-5,10,1))
plt.plot(x,y,'b')
plt.plot(x,y2,'b')
plt.plot(3,0,'o')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.axvline(x=3,ymin=0.3,ymax=0.7,color='r')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:4: RuntimeWarning: invalid value encountered in sqrt

# %%
a=-5,5
x=np.arange(a[0],a[1],0.01)
y2=-y
lims=[a[0],a[1],-5,5]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-5,10,1))
plt.plot(x,y,'b')
plt.plot(x,y2,'b')
plt.plot(0,0,'o')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()

# %%
a=-13,10
x=np.arange(a[0],a[1],0.01)
y=-(1/16.)*x**2-(1/4.)*x+7/4.
lims=[a[0],a[1],-10,3]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-15,10,1))
plt.plot(x,y,'b')
#plt.plot(x,y2,'b')
plt.plot(-2,-2,'o')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()

# %%
a=-9,6
x=np.arange(a[0],a[1],0.01)
y=1/12.*(x+3./2)**2-1
lims=[a[0],a[1],-2,4]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-15,10,1))
plt.plot(x,y,'b')
#plt.plot(x,y2,'b')
plt.plot(-3/2.,2.,'o')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()

# %%
a=-5,15
x=np.arange(a[0],a[1],0.01)
lims=[a[0],a[1],-4,5]
fig=plt.figure(figsize=(7,7))
y2=(1/14.)*x**2-(5./7)*x-17/14.
plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-15,10,1))
plt.plot(x,y2,'b')
plt.plot(5.,1/2.,'o')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()

# %%
a=0,18
x=np.arange(a[0],a[1],0.01)
y = (1/7.)*x**2-(18./7)*x+88/7.
lims=[a[0],a[1],0,12]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-20,20,1))
plt.plot(x,y,'b')
#plt.plot(x,y2,'b')
plt.plot(9,17./4.,'o')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()

# %%
a=-1,8
x=np.arange(a[0],a[1],0.001)
y =-4+np.sqrt(-3*x+15)
lims=[a[0],a[1],-9,1]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-20,20,1))
plt.plot(x,y,'b')
y=-4-np.sqrt(-3*x+15)
plt.plot(x,y,'b')
plt.plot(9,17./4.,'o')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.axvline(x=23./4,color='r')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:12: RuntimeWarning: invalid value encountered in sqrt

# %%
a=-15,-5
x=np.arange(a[0],a[1],0.001)
y=2+3*np.sqrt(-x-9)
lims=[a[0],a[1],-6,10]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-20,20,1))
plt.plot(x,y,'b')
y=2-3*np.sqrt(-x-9)
plt.plot(x,y,'b')
plt.plot(9,17./4.,'o')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.axvline(x=-27./4,color='r')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:12: RuntimeWarning: invalid value encountered in sqrt

# %%
a=-5,5
x=np.arange(a[0],a[1],0.001)
y=np.sqrt(4*(x+3))
lims=[a[0],a[1],-6,6]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-20,20,1))
plt.plot(x,y,'b')
plt.plot(x,-y,'b')
plt.plot(9,17./4.,'o')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.axvline(x=-4,color='r')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()

# %%
a=-5,5
x=np.arange(a[0],a[1],0.001)
y = -(1./8)*x**2+2
lims=[a[0],a[1],-6,6]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-20,20,1))
plt.plot(x,y,'b')
plt.plot(9,17./4.,'o')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
#plt.axhline(y=4,color='r')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()

# %%
a=-5,0
x=np.arange(a[0],a[1],0.001)
y =-1+(1./2)*np.sqrt(6*x+18)
lims=[a[0],a[1],-4,2]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-20,20,1))
plt.plot(x,y,'b')
y=-1-(1/2.)*np.sqrt(6*x+18)
plt.plot(x,y,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
#plt.plot(-21/8.,-1,'o')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:12: RuntimeWarning: invalid value encountered in sqrt

# %%
a=-17,17
x=np.arange(a[0],a[1],0.001)
y=3+np.sqrt(x-2)
y2=3-np.sqrt(x-2)

y3=1/900.*x**2+5
y4=-7.*x**2+2
y5=3-3*np.sqrt(-x-5)
y6=3+3*np.sqrt(-x-5)
lims=[a[0],a[1],-5,10]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
plt.plot(x,y3,'g')
plt.plot(x,y,'b')
plt.plot(x,y2,'b')
plt.plot(x,y4,'r')
plt.plot(x,y5,'y')
plt.plot(x,y6,'y')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:4: RuntimeWarning: invalid value encountered in sqrt
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:8: RuntimeWarning: invalid value encountered in sqrt
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:9: RuntimeWarning: invalid value encountered in sqrt

# %%
a=-3,9
x=np.arange(a[0],a[1],0.001)
y = -2+(2./3)*np.sqrt(-5*x**2+30*x)

lims=[a[0],a[1],-7,4]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-20,20,1))
plt.plot(x,y,'b')
y = -2-(2./3)*np.sqrt(-5*x**2+30*x)
plt.plot(x,y,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:13: RuntimeWarning: invalid value encountered in sqrt

# %%
a=-7,3
x=np.arange(a[0],a[1],0.001)
y=3+(1/3.)*np.sqrt(-3*x**2-12*x+33)

lims=[a[0],a[1],-1,9]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-20,20,1))
plt.plot(x,y,'b')
y=3-(1/3.)*np.sqrt(-3*x**2-12*x+33)
plt.plot(x,y,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:13: RuntimeWarning: invalid value encountered in sqrt

# %%
a=-7,3
x=np.arange(a[0],a[1],0.001)
y = 3+(3./10)*np.sqrt(-5*x**2-20*x+80)

lims=[a[0],a[1],-1,9]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-20,20,1))
plt.plot(x,y,'b')
y = 3-(3./10)*np.sqrt(-5*x**2-20*x+80)
plt.plot(x,y,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:13: RuntimeWarning: invalid value encountered in sqrt

# %%
import matplotlib.patches as patch
a=-7,13
x=np.arange(a[0],a[1],0.001)
y = -3+(3./5)*np.sqrt(x**2-6*x+34)

lims=[a[0],a[1],-10,4]
fig=plt.figure(figsize=(7,7))
ax1 = fig.add_subplot(111, aspect='equal')
plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-20,20,1))
plt.plot(x,y,'b')
y = -3-(3/5.)*np.sqrt(x**2-6*x+34)
plt.plot(x,y,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()

# %%
import matplotlib.patches as patch
a=-12,2
x=np.arange(a[0],a[1],0.001)
y = 2+(3./2)*np.sqrt(x**2+10*x+41)

lims=[a[0],a[1],-10,14]
fig=plt.figure(figsize=(7,7))
ax1 = fig.add_subplot(111, aspect='equal')
ax1.add_patch(patch.Rectangle((-9, -4),8,12,fill=False,edgecolor='r'))
fig.savefig('rect1.png', dpi=90, bbox_inches='tight')
plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-20,20,1))
plt.plot(-5,2,'o')
plt.plot(x,y,'b')
y = 2-(3./2)*np.sqrt(x**2+10*x+41)
plt.plot(x,y,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()

# %%
import matplotlib.patches as patch
a=-6,6
x=np.arange(a[0],a[1],0.001)
y = 1+(2/3.)*np.sqrt(x**2+9)

lims=[a[0],a[1],-4,6]
fig=plt.figure(figsize=(7,7))
ax1 = fig.add_subplot(111, aspect='equal')
ax1.add_patch(patch.Rectangle((-3, -1),6,4,fill=False,edgecolor='r'))
fig.savefig('rect1.png', dpi=90, bbox_inches='tight')
plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-20,20,1))
plt.plot(0,1,'o')
plt.plot(x,y,'b')
y = 1-(2/3.)*np.sqrt(x**2+9)
plt.plot(x,y,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()

# %%
import matplotlib.patches as patch
a=-1,5
x=np.arange(a[0],a[1],0.001)
y = np.exp(-2*x)-4

lims=[a[0],a[1],-5,4]
fig=plt.figure(figsize=(7,7))
ax1 = fig.add_subplot(111)
fig.savefig('plot1.png', dpi=90, bbox_inches='tight')
plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-20,20,1))
plt.plot(x,y,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()

# %%
a=-5,5
x=np.arange(a[0],a[1],0.001)
y1 = np.exp(x)
y2=-np.log(-x)
y3=np.log(x)
y4=np.exp(-x)
lims=[a[0],a[1],-5,4]
fig=plt.figure(figsize=(7,7))
ax1 = fig.add_subplot(111)
fig.savefig('plot1.png', dpi=90, bbox_inches='tight')
plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-20,20,1))
plt.plot(x,y1,'b')
plt.plot(x,y2,'r')
plt.plot(x,y3,'g')
plt.plot(x,y4,'y')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:4: RuntimeWarning: invalid value encountered in log
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:5: RuntimeWarning: invalid value encountered in log

# %%
Anios=np.arange(1950,2011,10)
Anios2=np.append(Anios,2016) #PEA
Anios3=np.append(Anios,2015) #PPC, Pob
Mexico={'Poblacion':[27.,35.,48.,66.,90.,98.,118.,119.],'PEA':[8.,11.,14.,22.,30.,39.,50.,56.],'PNB':[5.,17.,33.,98.,315.,600.,1050.],'PPC':
        [190.,490.,690.,1470.,4000.,7500.,8900.,9000.]}
EU={'Poblacion':[153,180,203,226,250,270,309,319],'PEA':[60,70,79,103,126,140,157,161],'PNB':[1200,1500,2000,3000,4000,7200,14900],
    'PPC':[5000,10600,14300,16800,23000,32400,48300,55800]}
def fusion(a,b):
    return [item for sublist in zip(a,b) for item in sublist]
CocPob=np.divide(EU["Poblacion"],Mexico["Poblacion"])
CocPEA=np.divide(EU["PEA"],Mexico["PEA"])
CocPNB=np.divide(EU["PNB"],Mexico["PNB"])
CocPPC=np.divide(EU["PPC"],Mexico["PPC"])
def deriv(y,x):
    dy=[(y[i+1]-y[i])/(x[i+1]-x[i]) for i in range(0,len(x)-1)]
    dy.append((y[i]-y[i-1])/(x[i]-x[i-1]))
    return dy

plt.plot(Anios3,CocPob)
plt.title(u"Veces que supera Estados Unidos a México en cuanto a población\n",fontsize=14)
plt.xlabel(u"Años")
plt.show()
plt.plot(Anios2,CocPEA)
plt.title(u"Veces que supera Estados Unidos a México en cuanto a PEA\n",fontsize=14)
plt.xlabel(u"Años")
plt.show()
plt.plot(Anios,CocPNB)
plt.title(u"Veces que supera Estados Unidos a México en cuanto a PNB\n",fontsize=14)
plt.xlabel(u"Años")
plt.show()
plt.plot(Anios3,CocPPC)
plt.title(u"Veces que supera Estados Unidos a México en cuanto a PPC\n",fontsize=14)
plt.xlabel(u"Años")
plt.show()

lims=[1950,2014,0,3]
plt.axis(lims)
plt.plot(Anios3,deriv(Mexico["Poblacion"],Anios3),label=u"México")
plt.plot(Anios3,deriv(EU["Poblacion"],Anios3),color='r',label=u"Estados Unidos")
plt.title(u"Crecimiento de la población de los países en millones de habitantes por año\n",fontsize=14)
plt.xlabel(u"Años")
plt.ylabel(u"Crecimiento [Millones de habitantes por año]")
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)

plt.show()

lims=[1950,2015,0,3]
plt.axis(lims)
plt.plot(Anios3,deriv(Mexico["PEA"],Anios2),label=u"México")
plt.plot(Anios3,deriv(EU["PEA"],Anios2),color='r',label=u"Estados Unidos")
plt.title(u"Crecimiento de la PEA de los países en millones de habitantes por año\n",fontsize=14)
plt.xlabel(u"Años")
plt.ylabel(u"Crecimiento [Millones de habitantes por año]")
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.show()


plt.plot(Anios,deriv(Mexico["PNB"],Anios),label=u'México')
plt.plot(Anios,deriv(EU["PNB"],Anios),color='r',label=u"Estados Unidos")
plt.title(u"Crecimiento del PNB de los países en miles de millones de dólares por año\n",fontsize=14)
plt.xlabel(u"Años")
plt.ylabel(u"Crecimiento [Miles de millones de dólares por año]")
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.show()


lims=[1950,2014,0,1800]
plt.axis(lims)
plt.plot(Anios3,deriv(Mexico["PPC"],Anios3),label=u'México')
plt.plot(Anios3,deriv(EU["PPC"],Anios3),color='r',label=u"Estados Unidos")
plt.title(u"Crecimiento del PPC de los países en dólares por habitante por año\n",fontsize=14)
plt.xlabel(u"Años")
plt.ylabel(u"Crecimiento [Dólares por habitante por año]")
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)
plt.show()

# %%
a=-4,0
x=np.arange(a[0],a[1],0.01)
y=4*x**2-3*x+2
lims=[a[0]-1,a[1]+1,0,80]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0]-1,a[1]+2,1))
ax.set_yticks(np.arange(0,100,10))
plt.plot(x,y,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.show()

# %%
a=9,100
x=np.arange(a[0],a[1],0.01)
y=np.sqrt(x+3)
lims=[0,a[1]+10,0,12]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(0,a[1]+20,10))
ax.set_yticks(np.arange(0,100,1))
plt.plot(x,y,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.show()

# %%
a=-5,0
x=np.arange(a[0],a[1],0.01)
y=((x+2)+1)*((x+2)-1)*((x+2)+2)+10
lims=[a[0],a[1],2,18]
fig=plt.figure(figsize=(7,7))

ax = fig.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xticks([],[])
plt.yticks([],[])
plt.axis(lims)
plt.plot(x,y,'b')
y = 14.98917323+1.228346457*x
plt.plot(x,y,'--b',label='Secante')
y = 16.90147975+5.052959503*x
plt.plot(x,y,'--g',label='Secante')
y = 11.75000000*x+20.25000000
plt.plot(x,y,'-r',label='Tangente')
plt.plot(-3.548,10.631,'o')
plt.plot(-1.784,7.887,'o')
plt.plot(-0.5,14.375,'or')
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.,fontsize=18)
plt.xlabel(r'$x$',fontsize=18)
plt.ylabel(r'$y$',fontsize=18)
plt.show()

# %%
x=np.arange(0,3000,1)
I=100*x
E=36500+34.5*x
lims=[0,3000,0,350000]
fig=plt.figure(figsize=(7,7))

ax = fig.gca()
plt.axis(lims)
plt.plot(x,I,'b',label='Ingresos')
plt.plot(x,E,'--r',label='Egresos')
plt.plot(557,55725,'o')
ax.text(557,30725,"Punto de Equilibrio\n (557,55725)")
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.,fontsize=18)
plt.xlabel('Unidades vendidas',fontsize=18)
plt.ylabel('$',fontsize=18)
plt.show()

# %%
a=0,10
x=np.arange(a[0],a[1],0.01)
y=-3/2.+(1/2.)*np.sqrt(-7+4*x)
y2=-3/2.-(1/2.)*np.sqrt(-7+4*x)
lims=[a[0],a[1],-5,1]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-5,10,1))
plt.plot(x,y,'b')
plt.plot(x,y2,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:4: RuntimeWarning: invalid value encountered in sqrt

# %%
a=-5,1
x=np.arange(a[0],a[1],0.01)
y=x**2+3*x+4
lims=[a[0],a[1],0,10]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-5,10,1))
plt.plot(x,y,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()

# %%
a=0,10
x=np.arange(a[0],a[1],0.01)
y=-3/2.+(1/2.)*np.sqrt(-7+4*x)
y2=-3/2.-(1/2.)*np.sqrt(-7+4*x)
lims=[a[0],a[1],-2,5]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-5,10,1))
plt.plot(x,-y,'b')
plt.plot(x,-y2,'b')
plt.axhline(y=0,color='k')
plt.axis(lims)
plt.axvline(x=0,color='k')
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()
# Out:
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# C:\Users\Guillermo1\AppData\Local\Enthought\Canopy\User\lib\site-packages\ipykernel\__main__.py:4: RuntimeWarning: invalid value encountered in sqrt

# %%
a=-5,1
x=np.arange(a[0],a[1],0.01)
y=x**2+3*x+4
lims=[a[0],a[1],-6,0]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-5,10,1))
plt.plot(x,-y,'b')
plt.axhline(y=0,color='k')
plt.axvline(x=0,color='k')
plt.axis(lims)
plt.ylabel(r'$y$')
plt.xlabel(r'$x$')
plt.show()

# %%
x=np.linspace(-10,10,20)
y=np.linspace(-10,10,20)
x,y=np.meshgrid(x,y)
lims=[-5,5,-5,5]
fig=plt.figure(figsize=(7,7))
ax=plt.axes()

ax.arrow(0,0,3,2,head_width=0.1, head_length=0.2,fc='k',ec='k')
ax.text(3,2.4,r"$F_1$",fontsize=18)

ax.arrow(0,0,-2,1,head_width=0.1, head_length=0.2,fc='k',ec='k')
ax.text(-2,1.5,r"$F_2$",fontsize=18)

ax.arrow(0,0,4,-4,head_width=0.1, head_length=0.2,fc='k',ec='k')
ax.text(4,-4+0.4,r"$F_4$",fontsize=18)

ax.arrow(0,0,-3,-1,head_width=0.1, head_length=0.2,fc='k',ec='k')
ax.text(-3,-1+0.4,r"$F_3$",fontsize=18)

ax.set_xticks(np.arange(-5,5,1))
ax.set_yticks(np.arange(-5,5,1))
plt.grid(True)
plt.axis(lims)
plt.axhline(y=0,color='k')
plt.axvline(x=0,color='k')

plt.ylabel(r'$y$ $\left[ N\right]$',fontsize=18)
plt.xlabel(r'$x$ $\left[ N\right]$',fontsize=18)

plt.plot()
plt.show()

# %%
a=-2,3
x=np.arange(a[0],a[1],0.01)
y=3*x**3-5*x**2-x+5
lims=[a[0],a[1],-1,8]
fig=plt.figure(figsize=(7,7))

plt.grid(True)
ax = fig.gca()
ax.set_xticks(np.arange(a[0],a[1]+1,1))
ax.set_yticks(np.arange(-15,10,1))
plt.plot(x,y,'b')
plt.plot(0.556,3.416,'o')
plt.plot(-.8775290574,0,'yo')
plt.plot(1.203439099,1.783931157,'o')
plt.plot(-0.923279882e-1,5.047344563,'o')
plt.plot(2,7,'wo')
#ax.text(0.556-0.2,3.416+0.6,u"Punto de inflexión",fontsize=12)
plt.axhline(y=0,color='k')
plt.axvline(x=0,color='k')
plt.axis(lims)
plt.ylabel(r'$y$',fontsize=18)
plt.xlabel(r'$x$',fontsize=18)
plt.show()

# %%
x=np.linspace(-10,10,20)
y=np.linspace(-10,10,20)
x,y=np.meshgrid(x,y)
lims=[-3,7,-3,7]
fig=plt.figure(figsize=(7,7))
ax=plt.axes()

ax.arrow(0,0,2-0.1,3-0.1,head_width=0.1, head_length=0.2,fc='b',ec='b')
ax.text(2-0.4,3.4,r"$F$",fontsize=18)

ax.arrow(0,0,-(2-0.1),-(3-0.1),head_width=0.1, head_length=0.2,fc='r',ec='r')
ax.text(-2-0.4,-3+.4,r"$-F$",fontsize=18)

ax.arrow(0,-0.1,4-0.15,6-0.15,head_width=0.1, head_length=0.2,fc='k',ec='k')
ax.text(4-0.4,6.4,r"$2F$",fontsize=18)

ax.set_xticks(np.arange(-5,15,1))
ax.set_yticks(np.arange(-5,15,1))
plt.grid(True)
plt.axis(lims)
plt.axhline(y=0,color='k')
plt.axvline(x=0,color='k')

plt.ylabel(r'$y$',fontsize=18)
plt.xlabel(r'$x$',fontsize=18)

plt.plot()
plt.show()

# %%
x=np.linspace(-10,10,20)
y=np.linspace(-10,10,20)
x,y=np.meshgrid(x,y)
lims=[-1,3,-1,6]
fig=plt.figure(figsize=(7,7))
ax=plt.axes()

ax.arrow(0,0,2-0.1,3-0.1,head_width=0.1, head_length=0.2,fc='b',ec='b')
ax.text(2-0.4,2,r"$F$",fontsize=18)

ax.arrow(0,2,2-0.1,3-0.1,head_width=0.1, head_length=0.2,fc='b',ec='b')
ax.text(1.5,3+1.8,r"$F$",fontsize=18)

ax.arrow(0,0,0,2-0.1,head_width=0.1, head_length=0.2,fc='r',ec='r')
ax.text(0,2-.4,r"$E$",fontsize=18)

ax.arrow(2,3,0,2-0.1,head_width=0.1, head_length=0.2,fc='r',ec='r')
ax.text(2,5.4,r"$E$",fontsize=18)

ax.arrow(0,0,2-0.09,5-0.1,head_width=0.1, head_length=0.2,fc='purple',ec='purple')
ax.text(0.5,2.5,r"$F+E$",fontsize=18)

ax.set_xticks(np.arange(-5,15,1))
ax.set_yticks(np.arange(-5,15,1))
plt.grid(True)
plt.axis(lims)
plt.axhline(y=0,color='k')
plt.axvline(x=0,color='k')

plt.ylabel(r'$y$',fontsize=18)
plt.xlabel(r'$x$',fontsize=18)

plt.plot()
plt.show()
